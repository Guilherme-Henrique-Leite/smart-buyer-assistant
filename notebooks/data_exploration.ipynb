# %% [markdown]
# Imports

# %%
import sys
sys.path.append('../')
from src.utils.imports import *

# %% [markdown]
# Load Data

# %%
csv_file = os.path.join(path, "ratings_Beauty.csv")
df_customers = pd.read_csv(csv_file, names=['userId', 'productId', 'rating', 'timestamp'], low_memory=False)

# %% [markdown]
# Exploration Data

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023071 entries, 0 to 2023070
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     object
#  1   productId  object
#  2   rating     object
#  3   timestamp  object
# dtypes: object(4)
# memory usage: 61.7+ MB

# %%
df_customers.isnull().sum()
# Out:
# userId       0
# productId    0
# rating       0
# timestamp    0
# dtype: int64

# %%
df_customers.head()
# Out:
#            userId   productId  rating   timestamp
# 0          UserId   ProductId  Rating   Timestamp
# 1  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 2  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 3  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 4  A1WMRR494NWEWV  0733001998     4.0  1382572800

# %%
df_customers.describe()
# Out:
#                 userId   productId   rating   timestamp
# count          2023071     2023071  2023071     2023071
# unique         1210272      249275        6        4232
# top     A3KEZLJ59C1JVH  B001MA0QY2      5.0  1380672000
# freq               389        7533  1248721        5813

# %% [markdown]
# Visualization

# %%
sns.histplot(df_customers['rating'], bins=10, kde=True)
plt.title("Distribuição das Avaliações")
plt.xlabel("Rating")
plt.ylabel("Frequência")
plt.show()

# %%
user_ratings_count = df_customers['userId'].value_counts()

# %%
sns.histplot(user_ratings_count, bins=50, kde=True)
plt.title("Número de Avaliações por Usuário")
plt.xlabel("Número de Avaliações")
plt.ylabel("Frequência")
plt.show()

# %%
product_ratings_count = df_customers['productId'].value_counts()

# %%
sns.histplot(product_ratings_count, bins=50, kde=True)
plt.title("Número de Avaliações por Produto")
plt.xlabel("Número de Avaliações")
plt.ylabel("Frequência")
plt.show()

# %%
sns.boxplot(x=df_customers['rating'])
plt.title("Boxplot das Avaliações")
plt.show()
